# %%
import plotly.graph_objects as go

ppl = ('Mark','John','Daniel','Greg')
salary = (1000,1500,2300,5000)


fig = go.Figure(data=[go.Bar(x=ppl, y=salary)])
fig.update_layout(title="Salaries in Plotly")
fig.show()
